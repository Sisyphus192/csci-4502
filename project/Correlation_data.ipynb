# %%
import pandas as pd
import numpy as np
from collections import OrderedDict
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns
from util import parse_ingredient_list
from itertools import chain
import re
import json
import nltk
import pycrfsuite
import spacy.lang.en

# %%
# load one of the datasets to look at
file_name = "recipes_raw_nosource_ar"
df = pd.read_json("data/"+file_name+".json")
df.head()
# Out:
#                                 ../AFIrLizRK7C5isREQ0hUdXoNXTpS  \
# ingredients   [2 1/2 cups creamy salad dressing (such as Mir...
# instructions  Mix creamy salad dressing, mustard, sugar, and...
# picture_link                    C0dLeqJsHiETBZCxg4uw0aqGvrSjRea
# title                                  Creamy Deviled Egg Salad
#
#                                 ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2  \
# ingredients   [1 3/4 cups white sugar, 8 cups water, 1 1/2 c...
# instructions  In a small saucepan, combine sugar and 1 cup w...
# picture_link                    yjOAxAZN21c1IpdKlxm/AXmuxqW2dz.
# title                                        Best Lemonade Ever
#
#                                 ..64QbeV22IrPuRAdLu4zscfAjsaFaK  \
# ingredients   [2 cups baking mix, 1/2 cup shredded Cheddar c...
# instructions  Preheat an oven to 450 degrees F (230 degrees ...
# picture_link                    i15jQbCInVmWa4z/CZbfodtgmapiGlG
# title                                    Cheddar Beer Triangles
#
#                                 ..6gl/0GIzSugrbvy6kHyxEHMMP4h9K  \
# ingredients   [2 teaspoons olive oil, 1 cup chopped onion, 2...
# instructions  In a large saucepan, heat oil over medium heat...
# picture_link                    hirHYG7xYneTopSvOWRmO5vgv81gR8C
# title                               Sicilian Lentil Pasta Sauce
#
#                                 ..B3IS4KrEGWH7o13lvV9nQSe9a4u36  \
# ingredients   [1/2 cup uncooked long-grain rice, 6 slices ba...
# instructions  Preheat oven to 350 degrees F (175 degrees C)....
# picture_link                    c7O73YtdFisiVWx9Hetm6YiCV/zPZA.
# title                                 Broccoli Cheese Casserole
#
#                                 ..G2iuRLT7oseNmkKbjqAgbdB1G5IBC  \
# ingredients   [10 fresh tomatillos, husks removed, 3 cloves ...
# instructions  Bring the tomatillos, garlic cloves, and water...
# picture_link                    OMYSXuFXYpYbXehIDrOOgj8oj7WQEki
# title            Salsa de Tomatillos Como Las Asadas y Big Star
#
#                                 ..M776r8BHroHcCXw3vInfs25LDkWw2  \
# ingredients   [1 pound ground beef, 1 onion, chopped, 1 (14....
# instructions  In a large saucepan over medium-high heat, coo...
# picture_link                    aj./uBh.r3nGhTNH/K5RhCVaYOChpS2
# title                                           Melanie's Chili
#
#                                 ..VDFobAHiAa0127h.N784Y2pnZyBZK  \
# ingredients   [1/2 pound uncooked medium shrimp, peeled and ...
# instructions  Place the shrimp, shallot, 1 clove of garlic, ...
# picture_link                    MeEgA1rybCmDKGORjjn0h8RW2FpkGC6
# title           Dee's Sexy, Spicy, Shrimp, Sausage, and Peppers
#
#                                 ..hYtxdDoy5Rp..pLgIj2mKKfvp1jPa  \
# ingredients   [1 onion, quartered, 2 fresh green chile peppe...
# instructions  Blend the onion, green chile peppers, mint, le...
# picture_link                    fs4UZW7cHDQdzGNt/TWKUkT0HLVD31y
# title                                        Minty Mint Chutney
#
#                                 ..r9vTQ.rPxKBEmr5CeouYRueErDR9u  \
# ingredients   [1/4 cup butter, 1/2 cup chopped carrots, 1/2 ...
# instructions  Melt butter in large saucepan over medium heat...
# picture_link                    cH1T70Drd2oK8fY6HrVr25u0vbDhPf6
# title                                            Artichoke Soup
#
#                                     ...                          \
# ingredients                         ...
# instructions                        ...
# picture_link                        ...
# title                               ...
#
#                                 zzQI40IqH266Q/7aL2dNUcSLDfAw5TK  \
# ingredients   [1 cup cornmeal, 2 teaspoons ground cayenne pe...
# instructions  In a mixing bowl, stir together cornmeal, caye...
# picture_link                    cnUsX.u0W5EGqDZvMPdTCslIPmF2QBW
# title                                  Pan Fried Catfish Filets
#
#                                 zzSHIhnBtnBz777ZKFY2M3z.ohnLwtm  \
# ingredients   [1/4 cup prepared salsa, 1 1/2 tablespoons shr...
# instructions  Preheat oven to 375 degrees F (190 degrees C)....
# picture_link                    ./lHrbu3IthePiUvtCH6c4nO0fDf6za
# title                                   Cheese Quesadilla Lunch
#
#                                 zzbj22/DDmvJZum5LsBbXj8MfckHzBO  \
# ingredients   [1 pound lean ground beef, 1 pound lean ground...
# instructions  In a large stock pot over medium heat, brown t...
# picture_link                    nxmhzsWZRIrjoOMo8UUKBttikgEGzg2
# title                                       Doug's Killer Sauce
#
#                                 zzkKyv6S9eERX/S2GPg6zuLy.UUY3Ya  \
# ingredients   [1 tablespoon vegetable oil, 1 onion, chopped,...
# instructions  In large saucepan, heat oil over medium heat; ...
# picture_link                    CFa1fSzQ.JteZcdSgjWzsKG8qrvBPJK
# title                                 Black Bean Vegetable Soup
#
#                                 zzor9kQO5E07Pn81ENqTxc4VA1ivct2  \
# ingredients   [2 tablespoons sesame oil, 1 tablespoon brown ...
# instructions  Heat the sesame oil in a large skillet over me...
# picture_link                    drfDSrS/fHI4sCDoTqYkaVqMVKHRkjW
# title                  Japanese Spinach with Sweet Sesame Seeds
#
#                                 zzp8k7XnnQzjZgsZZgvbBwjwdCV7UOy  \
# ingredients   [1 cup ice cubes, 6 chunks fresh pineapple, 3 ...
# instructions  Divide ice cubes between 2 martini glasses to ...
# picture_link                    qE58a7Z1Au0GXvPO188iHZZVqna9hLa
# title                                  Golden Tropical Cocktail
#
#                                 zzrUjH6/V3BmYZ/PufrjaI28bG.y8fe  \
# ingredients   [1 3/4 cups granulated sugar, 4 eggs, 4 ounces...
# instructions  Combine the granulated sugar, eggs, melted cho...
# picture_link                    Vu/f9S95lEQakSNV540dUA5SQje63oi
# title                            Chocolate Mint Crinkle Cookies
#
#                                 zzsdaZomiWhwU0uej/xv4WHFV.T5Yq.  \
# ingredients   [1 (18.25 ounce) package white cake mix, 1 tea...
# instructions  Grease and flour two 9 inch pans. Prepare cake...
# picture_link                    fjzMGNfR3lBeijCn98DKs12ASqiMPsS
# title                                   Coconut Sour Cream Cake
#
#                                 zzu0ElHFK71GznRt6JcB9vRym3/M1le  \
# ingredients   [1 1/2 cups water, 1 1/2 cups white sugar, 1 (...
# instructions  Combine the water, sugar, ginger, salt, and li...
# picture_link                    GKA98G/FHvqnY1yFOnGqcy0bXnIUALS
# title                          Orange, Mango, and Ginger Sorbet
#
#                                 zzwS69D.4D3Ygbw0sZ4Sp.5t0KdUTYi
# ingredients   [1 (18.25 ounce) package yellow cake mix, 3 eg...
# instructions  Preheat oven to 350 degrees F (175 degrees C)....
# picture_link                    TAoVBMrlGtKB9Q34uJ5Jca1H/0y6e1e
# title                                            Apple Cake III
#
# [4 rows x 39802 columns]

# %%
# For the moment we are not interested in the instructions or picture_link
df.drop(["instructions", "picture_link"], inplace=True)
df.head()
# Out:
#                                ../AFIrLizRK7C5isREQ0hUdXoNXTpS  \
# ingredients  [2 1/2 cups creamy salad dressing (such as Mir...
# title                                 Creamy Deviled Egg Salad
#
#                                ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2  \
# ingredients  [1 3/4 cups white sugar, 8 cups water, 1 1/2 c...
# title                                       Best Lemonade Ever
#
#                                ..64QbeV22IrPuRAdLu4zscfAjsaFaK  \
# ingredients  [2 cups baking mix, 1/2 cup shredded Cheddar c...
# title                                   Cheddar Beer Triangles
#
#                                ..6gl/0GIzSugrbvy6kHyxEHMMP4h9K  \
# ingredients  [2 teaspoons olive oil, 1 cup chopped onion, 2...
# title                              Sicilian Lentil Pasta Sauce
#
#                                ..B3IS4KrEGWH7o13lvV9nQSe9a4u36  \
# ingredients  [1/2 cup uncooked long-grain rice, 6 slices ba...
# title                                Broccoli Cheese Casserole
#
#                                ..G2iuRLT7oseNmkKbjqAgbdB1G5IBC  \
# ingredients  [10 fresh tomatillos, husks removed, 3 cloves ...
# title           Salsa de Tomatillos Como Las Asadas y Big Star
#
#                                ..M776r8BHroHcCXw3vInfs25LDkWw2  \
# ingredients  [1 pound ground beef, 1 onion, chopped, 1 (14....
# title                                          Melanie's Chili
#
#                                ..VDFobAHiAa0127h.N784Y2pnZyBZK  \
# ingredients  [1/2 pound uncooked medium shrimp, peeled and ...
# title          Dee's Sexy, Spicy, Shrimp, Sausage, and Peppers
#
#                                ..hYtxdDoy5Rp..pLgIj2mKKfvp1jPa  \
# ingredients  [1 onion, quartered, 2 fresh green chile peppe...
# title                                       Minty Mint Chutney
#
#                                ..r9vTQ.rPxKBEmr5CeouYRueErDR9u  \
# ingredients  [1/4 cup butter, 1/2 cup chopped carrots, 1/2 ...
# title                                           Artichoke Soup
#
#                                    ...                          \
# ingredients                        ...
# title                              ...
#
#                                zzQI40IqH266Q/7aL2dNUcSLDfAw5TK  \
# ingredients  [1 cup cornmeal, 2 teaspoons ground cayenne pe...
# title                                 Pan Fried Catfish Filets
#
#                                zzSHIhnBtnBz777ZKFY2M3z.ohnLwtm  \
# ingredients  [1/4 cup prepared salsa, 1 1/2 tablespoons shr...
# title                                  Cheese Quesadilla Lunch
#
#                                zzbj22/DDmvJZum5LsBbXj8MfckHzBO  \
# ingredients  [1 pound lean ground beef, 1 pound lean ground...
# title                                      Doug's Killer Sauce
#
#                                zzkKyv6S9eERX/S2GPg6zuLy.UUY3Ya  \
# ingredients  [1 tablespoon vegetable oil, 1 onion, chopped,...
# title                                Black Bean Vegetable Soup
#
#                                zzor9kQO5E07Pn81ENqTxc4VA1ivct2  \
# ingredients  [2 tablespoons sesame oil, 1 tablespoon brown ...
# title                 Japanese Spinach with Sweet Sesame Seeds
#
#                                zzp8k7XnnQzjZgsZZgvbBwjwdCV7UOy  \
# ingredients  [1 cup ice cubes, 6 chunks fresh pineapple, 3 ...
# title                                 Golden Tropical Cocktail
#
#                                zzrUjH6/V3BmYZ/PufrjaI28bG.y8fe  \
# ingredients  [1 3/4 cups granulated sugar, 4 eggs, 4 ounces...
# title                           Chocolate Mint Crinkle Cookies
#
#                                zzsdaZomiWhwU0uej/xv4WHFV.T5Yq.  \
# ingredients  [1 (18.25 ounce) package white cake mix, 1 tea...
# title                                  Coconut Sour Cream Cake
#
#                                zzu0ElHFK71GznRt6JcB9vRym3/M1le  \
# ingredients  [1 1/2 cups water, 1 1/2 cups white sugar, 1 (...
# title                         Orange, Mango, and Ginger Sorbet
#
#                                zzwS69D.4D3Ygbw0sZ4Sp.5t0KdUTYi
# ingredients  [1 (18.25 ounce) package yellow cake mix, 3 eg...
# title                                           Apple Cake III
#
# [2 rows x 39802 columns]

# %%
# Select a subset of data to look at, we transpose the original data frame
# so we can select all the values in a column at once.
df_trans = df.transpose()
# drop the recipes that have NaN for their ingredients
df_trans = df_trans[df_trans.ingredients.notnull()]

# %%
df_trans.head()
# Out:
#                                                                        ingredients  \
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  [2 1/2 cups creamy salad dressing (such as Mir...
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2  [1 3/4 cups white sugar, 8 cups water, 1 1/2 c...
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK  [2 cups baking mix, 1/2 cup shredded Cheddar c...
# ..6gl/0GIzSugrbvy6kHyxEHMMP4h9K  [2 teaspoons olive oil, 1 cup chopped onion, 2...
# ..B3IS4KrEGWH7o13lvV9nQSe9a4u36  [1/2 cup uncooked long-grain rice, 6 slices ba...
#
#                                                        title
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS     Creamy Deviled Egg Salad
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2           Best Lemonade Ever
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK       Cheddar Beer Triangles
# ..6gl/0GIzSugrbvy6kHyxEHMMP4h9K  Sicilian Lentil Pasta Sauce
# ..B3IS4KrEGWH7o13lvV9nQSe9a4u36    Broccoli Cheese Casserole

# %%
import utils
tagger = pycrfsuite.Tagger()
tagger.open('trained_pycrfsuite')

nlp_engine = spacy.lang.en.English()

from nltk.tokenize import PunktSentenceTokenizer
tokenizer = PunktSentenceTokenizer()

def sent2labels(sent):
    return [word[-1] for word in sent]

def sent2features(sent):
    return [word[:-1] for word in sent]

def sent2tokens(sent):
    return [word[0] for word in sent]   

def get_sentence_features(sent):
    """Gets  the features of the sentence"""
    sent_tokens = utils.tokenize(utils.cleanUnicodeFractions(sent))

    sent_features = []
    for i, token in enumerate(sent_tokens):
        token_features = [token]
        token_features.extend(utils.getFeatures(token, i+1, sent_tokens))
        sent_features.append(token_features)
    return sent_features

def format_ingredient_output(tagger_output, display=False):
    """Formats the tagger output into a more convenient dictionary"""
    data = [{}]
    display = [[]]
    prevTag = None

    
    for token, tag in tagger_output:
    # turn B-NAME/123 back into "name"
        tag = re.sub(r'^[BI]\-', "", tag).lower()
        # ---- DISPLAY ----
        # build a structure which groups each token by its tag, so we can
        # rebuild the original display name later.

        if prevTag != tag:
            display[-1].append((tag, [token]))
            prevTag = tag
        else:
            display[-1][-1][1].append(token)
            #               ^- token
            #            ^---- tag
            #        ^-------- ingredient

            # ---- DATA ----
            # build a dict grouping tokens by their tag

            # initialize this attribute if this is the first token of its kind
        if tag not in data[-1]:
            data[-1][tag] = []

        # HACK: If this token is a unit, singularize it so Scoop accepts it.
        if tag == "unit":
            token = utils.singularize(token)

        data[-1][tag].append(token)

    # reassemble the output into a list of dicts.
    output = [
        dict([(k, utils.smartJoin(tokens)) for k, tokens in ingredient.items()])
        for ingredient in data
        if len(ingredient)
    ]
    
    # Add the raw ingredient phrase
    for i, v in enumerate(output):
        output[i]["input"] = utils.smartJoin(
            [" ".join(tokens) for k, tokens in display[i]])

    return output

def parse_ingredient(sent):
    """ingredient parsing logic"""
    sentence_features = get_sentence_features(sent)
    tags = tagger.tag(sentence_features)
    tagger_output = zip(sent2tokens(sentence_features), tags)
    parsed_ingredient =  format_ingredient_output(tagger_output)
    if parsed_ingredient:
        parsed_ingredient[0]['name'] = parsed_ingredient[0].get('name','').strip('.')
    return parsed_ingredient

# %%
def parse_recipe_ingredients(ingredient_list):
    """Wrapper around parse_ingredient so we can call it on an ingredient list"""
    #sentences = tokenizer.tokenize(q)
    sentences = tokenizer.tokenize(ingredient_list)
    sentences = [sent.strip('\n') for sent in sentences]
    ingredients = []
    for sent in sentences:
        ingredients.extend(parse_ingredient(sent))
    return ingredients

def is_seperator(ingredient_string):
    return (
        ingredient_string.find("For ") == 0
        or " " not in ingredient_string
        or (":" in ingredient_string and "eg:" not in ingredient_string)
    )

# %%
s = "2 (10.75 ounce) cans condensed cream of mushr"
pattern = re.compile(r'([0-9]+)\s\(([0-9\.\sa-z]+)\)\s(\w+)')
match = re.sub(pattern, lambda x: str(int(x.group(1))*float(x.group(2).split()[0])) + " " + x.group(2).split()[1], s)
print(match)
# Out:
# 21.5 ounce condensed cream of mushr

# %%
pattern1 = re.compile(r'([0-9]+)\s\(([0-9\.]+\s[a-z]+)\)\s(\w+)')
pattern2 = re.compile(r'^([0-9]+)\s\(*([0-9\.\s\/]+)[\s\-](inch)[\sa-z]*\)*')

def parse_list(recipe_index, recipe_title, ingredient_list):
    if isinstance(ingredient_list, list):
        ingredients=[]
        for ingredient_string in ingredient_list:
            # check if not ingredient, but separator
            # e.g. "For Bread:"
            if is_seperator(ingredient_string):
                continue
                
            if "skewers" in ingredient_string:
                continue
                
            if "canning jars" in ingredient_string:
                continue
                
            # remove trademark symbols
            ingredient_string = ingredient_string.replace("\u00ae", "")
            ingredient_string = ingredient_string.replace("(TM)", "")
            ingredient_string = ingredient_string.replace("™", "")
            
            ingredient_string = re.sub(pattern1, lambda x: str(int(x.group(1))*float(x.group(2).split()[0])) + " " + x.group(2).split()[1], ingredient_string)
            match = re.search(pattern2, ingredient_string)
            if match:
                try:
                    qty = float(match.group(1))
                    mult = match.group(2).split()
                    if len(mult) == 2:
                        qty *= float(mult[0]) + eval(mult[1])
                    else:
                        qty *= eval(mult[0])
                    ingredient_string = re.sub(pattern2, str(qty) + " " + "inch", ingredient_string)
                except ValueError:
                    pass
            
            ingredient = {}

            #ingr = ingre_text[2]
            #print(ingr)
            ingr_parse = parse_recipe_ingredients(ingredient_string)
            #print(ingr_parse)
            ingredient = ingr_parse[0]
            ingredient["title"] = recipe_title
            ingredient["index"] = recipe_index
            if "qty" not in ingredient and "other" in ingredient:
                try:
                    ingredient["qty"] = float(ingredient["other"])
                    ingredient["other"] = np.nan
                except ValueError:
                    pass
            if "qty" in ingredient:
                if not isinstance(ingredient["qty"], float):
                    if "$" in ingredient["qty"]:
                        try:
                            frac = ingredient["qty"].split("$")
                            ingredient["qty"] = float(frac[0])+eval(frac[1])
                        except (ValueError, NameError):
                            pass
                    else:
                        try:
                            ingredient["qty"] = float(ingredient["qty"])
                        except ValueError:
                            ingredient["qty"] = np.nan
                            
                        

            ingredients.append(ingredient)
        return ingredients
    else:
        return recipe_index, recipe_title, None

# %%
vfunc = np.vectorize(parse_list)

ingredient_df = pd.DataFrame(
    list(
        chain.from_iterable(
            vfunc(
                df_trans.index.values,
                df_trans.title.values,
                df_trans["ingredients"].values,
            )
        )
    )
)
ingredient_df.set_index("index", inplace=True)

# %%
ingredient_df.head(10)
# Out:
#                                                                          comment  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                           (such as Miracle Whip)
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                                  prepared yellow
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                                              NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                                              NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  hard-boiled peeled and cut into 1/4-inch slices
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2                                              NaN
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2                                              NaN
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2                                              NaN
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK                                              NaN
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK                                         shredded
#
#                                                                              input  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  2$1/2 cups creamy salad dressing (such as Mira...
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                    3/4 cup prepared yellow mustard
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                                1/4 cup white sugar
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                        2 tablespoons white vinegar
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  12 hard-boiled eggs, peeled and cut into 1/4-i...
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2                             1$3/4 cups white sugar
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2                                       8 cups water
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2                             1$1/2 cups lemon juice
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK                                  2 cups baking mix
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK                    1/2 cup shredded Cheddar cheese
#
#                                                   name other    qty range_end  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  creamy salad dressing   NaN   2.50       NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                mustard   NaN    NaN       NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS            white sugar   NaN    NaN       NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS          white vinegar   NaN   2.00       NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                   eggs     ,  12.00       NaN
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2            white sugar   NaN   1.75       NaN
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2                  water   NaN   8.00       NaN
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2            lemon juice   NaN   1.50       NaN
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK             baking mix   NaN   2.00       NaN
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK         Cheddar cheese   NaN    NaN       NaN
#
#                                                     title        unit
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  Creamy Deviled Egg Salad         cup
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  Creamy Deviled Egg Salad         cup
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  Creamy Deviled Egg Salad         cup
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  Creamy Deviled Egg Salad  tablespoon
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  Creamy Deviled Egg Salad         NaN
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2        Best Lemonade Ever         cup
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2        Best Lemonade Ever         cup
# ..3M3xsVPQLnncQ2oYzCyhGjNe/6EB2        Best Lemonade Ever         cup
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK    Cheddar Beer Triangles         cup
# ..64QbeV22IrPuRAdLu4zscfAjsaFaK    Cheddar Beer Triangles         cup

# %%
ingredient_df.qty.unique()
# Out:
# array([2.50000000e+00,            nan, 2.00000000e+00, 1.20000000e+01,
#        1.75000000e+00, 8.00000000e+00, 1.50000000e+00, 1.00000000e+00,
#        3.00000000e+00, 1.60000000e+01, 6.00000000e+00, 1.00000000e+01,
#        1.05000000e+01, 4.00000000e+00, 1.45000000e+01, 1.50000000e+01,
#        1.75000000e+01, 4.20000000e+01, 3.00000000e+01, 7.00000000e+00,
#        1.25000000e+00, 2.50000000e-01, 3.50000000e+00, 1.40000000e+01,
#        3.20000000e+01, 2.80000000e+01, 5.00000000e+00, 2.25000000e+00,
#        7.00000000e-01, 4.50000000e+00, 1.07500000e+01, 3.10000000e+01,
#        1.76000000e+01, 1.52500000e+01, 1.82500000e+01, 2.10000000e+01,
#        3.60000000e+01, 9.00000000e+00, 2.00000000e+01, 2.40000000e+01,
#        2.75000000e+00, 2.90000000e+01, 6.40000000e+01, 2.15000000e+01,
#        4.80000000e+01, 6.30000000e+00, 1.55000000e+01, 1.90000000e+01,
#        3.25000000e+00, 3.40000000e+00, 4.00000000e+01, 5.00000000e-01,
#        2.80000000e+00, 1.80000000e+01, 2.60000000e+01, 2.50000000e+01,
#        1.95000000e+01, 1.44000000e+01, 5.50000000e+00, 1.27000000e+00,
#        2.30000000e+01, 7.50000000e+00, 1.35000000e+01, 1.63000000e+01,
#        1.10000000e+01, 4.50000000e+01, 5.60000000e+01, 4.60000000e+00,
#        6.80000000e+00, 4.25000000e+00, 3.90000000e+00, 6.00000000e+01,
#        8.00000000e+01, 5.00000000e+01, 3.75000000e+00, 9.00000000e+01,
#        1.30000000e+01, 4.90000000e+00, 1.85000000e+01, 5.40000000e+00,
#        2.20000000e+01, 8.75000000e+00, 1.30000000e+00, 4.20000000e+00,
#        4.30000000e+00, 1.15000000e+01, 7.75000000e+00, 1.24000000e+01,
#        3.10000000e+00, 7.50000000e+02, 6.50000000e+00, 1.65000000e+01,
#        7.80000000e+00, 5.80000000e+01, 5.25000000e+00, 6.00000000e-01,
#        4.57500000e+01, 3.15000000e+01, 4.35000000e+01, 5.90000000e+00,
#        1.47500000e+01, 3.30000000e+01, 8.80000000e+00, 5.30000000e-01,
#        1.42500000e+01, 1.70000000e+01, 1.02000000e+01, 7.80000000e+01,
#        5.10000000e+00, 3.00000000e+03, 1.98000000e+01, 6.75000000e+00,
#        3.22500000e+01, 2.40000000e+00, 7.60000000e+00, 7.50000000e-01,
#        1.12500000e+01, 2.60000000e+00, 1.96000000e+02, 7.20000000e+00,
#        1.40000000e+00, 8.50000000e+00, 7.20000000e+01, 7.50000000e+01,
#        3.80000000e+01, 2.55000000e+01, 1.37500000e+01, 8.40000000e+01,
#        1.25000000e+01, 1.50000000e+03, 2.25000000e+02, 9.60000000e+01,
#        1.41000000e+00, 8.25000000e+00, 8.70000000e-01, 7.25000000e+00,
#        5.60000000e+00, 1.28000000e+02, 9.60000000e+00, 1.30000000e-01,
#        3.05000000e+01, 1.17000000e+01, 2.05000000e+01, 1.41000000e+01,
#        1.12000000e+02, 6.60000000e+00, 2.60000000e-01, 2.25000000e+01,
#        1.30500000e+02, 7.25000000e+01, 2.75000000e+01, 5.70000000e+00,
#        4.75000000e+00, 3.50000000e+01, 1.80000000e+00, 8.70000000e+01,
#        7.60000000e+01, 1.73000000e+01, 9.74000000e+00, 1.02500000e+01,
#        1.70000000e+00, 4.05000000e+01, 5.80000000e+00, 2.20000000e+02,
#        4.37500000e+00, 1.45000000e+00, 5.20000000e+01, 1.87500000e+01,
#        5.30000000e+00, 1.46000000e+00, 8.40000000e+00, 8.30000000e+00,
#        1.72500000e+01, 4.40000000e+01, 8.80000000e-01, 2.65000000e+01,
#        1.80000000e-01, 1.38000000e+01, 1.32500000e+01, 2.10000000e+00,
#        1.10400000e+01, 5.20000000e-01, 1.06000000e+01, 4.60000000e+01,
#        5.30000000e+01, 3.66000000e+01, 3.30000000e+00, 2.70000000e+01,
#        1.68000000e+02, 1.20000000e+00, 3.30000000e+02, 4.32000000e+00,
#        8.40000000e+00, 5.40000000e+01, 6.90000000e+00, 1.00000000e+02,
#        1.22500000e+01, 4.65000000e+01, 1.23000000e+01, 1.13000000e+01,
#        1.12000000e+01, 2.95000000e+01, 5.50000000e+01, 3.65000000e+01,
#        1.05000000e+02, 6.48000000e+00, 2.64000000e+00, 1.12000000e+00,
#        1.20000000e+02, 3.48000000e+00, 3.16000000e+01, 2.14000000e+01,
#        7.90000000e+00, 1.69000000e+00, 1.07000000e+01, 9.00000000e-01,
#        8.70000000e+00, 4.30000000e+01, 6.20000000e+01, 1.69000000e+01,
#        1.04651163e+00, 1.10000000e+00, 5.50000000e-01, 4.42500000e+01,
#        6.87500000e+01, 1.90000000e+00, 2.82000000e+00, 8.64000000e+00,
#        3.70000000e+01, 1.26000000e+01, 3.60000000e+00, 6.33333333e+00,
#        6.60000000e+01, 1.37500000e+00, 3.26000000e+01, 1.55000000e+00,
#        1.62500000e+01, 6.40000000e+00, 1.24000000e+00, 4.40000000e+00,
#        1.49000000e+01, 9.75000000e+00, 3.04000000e+01, 2.88000000e+00,
#        2.20000000e+00, 6.50000000e+01, 4.00000000e-01, 1.80000000e+00,
#        8.60000000e+00, 1.52000000e+01, 1.18000000e+01, 2.45000000e+00,
#        4.65000000e+00, 1.45000000e+02, 9.25000000e+00, 3.45000000e+01,
#        2.25000000e+03, 1.74000000e+00, 5.20000000e+00, 8.90000000e+00,
#        1.58000000e+01, 6.30000000e+01, 6.10000000e+01, 4.00000000e+02,
#        2.00000000e+02, 7.33333333e+00, 2.88000000e+01, 5.70000000e+01,
#        5.37500000e+01, 3.90000000e+01, 7.20000000e+02, 6.25000000e+00,
#        4.66000000e+00, 5.40000000e-01, 7.00000000e+01, 1.54000000e+01,
#        1.70500000e+01, 1.47000000e+01, 6.30000000e+00, 1.31000000e+00,
#        5.75000000e+00, 6.76000000e+01, 4.20000000e+00, 9.30000000e+00,
#        1.62500000e+00, 9.50000000e+00, 3.40000000e+01, 2.12500000e+00,
#        6.20000000e+00, 3.20000000e+00, 3.95000000e+00, 1.68000000e+01,
#        1.48000000e+01, 1.08000000e+01, 3.75000000e+03, 3.46000000e+01,
#        2.85000000e+01, 3.80000000e+00, 4.12500000e+00, 2.88000000e+02,
#        4.27500000e+01, 2.70000000e+00, 3.96000000e+01, 1.76000000e+00,
#        1.26000000e+01, 4.10000000e+01, 2.90000000e+00, 1.06250000e+00,
#        8.33333333e+00, 1.14000000e+02, 1.46000000e+01, 1.16000000e+02])

# %%
# Now we convert as many units as possible to metric
ingredient_df.loc[ingredient_df.unit == "pound", "qty"] *= 453.592
ingredient_df.loc[ingredient_df.unit == "pound", "unit"] = "grams"

ingredient_df.loc[ingredient_df.unit == "teaspoon", "qty"] *= 4.92892
ingredient_df.loc[ingredient_df.unit == "teaspoon", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "tablespoon", "qty"] *= 14.7868
ingredient_df.loc[ingredient_df.unit == "tablespoon", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "cup", "qty"] *= 236.588
ingredient_df.loc[ingredient_df.unit == "cup", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "pinch", "qty"] *= 4.92892 * (1 / 16)
ingredient_df.loc[ingredient_df.unit == "pinch", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "dash", "qty"] *= 4.92892 * (1 / 8)
ingredient_df.loc[ingredient_df.unit == "dash", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "ounce", "qty"] *= 28.3495
ingredient_df.loc[ingredient_df.unit == "ounce", "unit"] = "grams"

ingredient_df.loc[ingredient_df.unit == "fluid ounce", "qty"] *= 29.5735
ingredient_df.loc[ingredient_df.unit == "fluid ounce", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "pint", "qty"] *= 473.176
ingredient_df.loc[ingredient_df.unit == "pint", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "quart", "qty"] *= 946.353
ingredient_df.loc[ingredient_df.unit == "quart", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "liter", "qty"] *= 1000
ingredient_df.loc[ingredient_df.unit == "liter", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "gallon", "qty"] *= 3785.41
ingredient_df.loc[ingredient_df.unit == "gallon", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "drop", "qty"] *= 0.05
ingredient_df.loc[ingredient_df.unit == "drop", "unit"] = "milliliters"

ingredient_df.loc[ingredient_df.unit == "jigger", "qty"] *= 44.3603
ingredient_df.loc[ingredient_df.unit == "jigger", "unit"] = "milliliters"

ingredient_df.head(2)
# Out:
#                                                 comment  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  (such as Miracle Whip)
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS         prepared yellow
#
#                                                                              input  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  2$1/2 cups creamy salad dressing (such as Mira...
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                    3/4 cup prepared yellow mustard
#
#                                                   name other     qty  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  creamy salad dressing   NaN  591.47
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                mustard   NaN     NaN
#
#                                 range_end                     title  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS       NaN  Creamy Deviled Egg Salad
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS       NaN  Creamy Deviled Egg Salad
#
#                                         unit
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  milliliters
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  milliliters

# %%
df_correlation = ingredient_df[['name',"qty",'unit']]
print(df_correlation.head(2))
df_correlation.to_pickle("data/correlation_data.pickle")
# Out:
#                                                   name     qty         unit
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  creamy salad dressing  591.47  milliliters
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                mustard     NaN  milliliters

# %%
ingredient_df.head()
# Out:
#                                                                          comment  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                           (such as Miracle Whip)
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                                  prepared yellow
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                                              NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                                              NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  hard-boiled peeled and cut into 1/4-inch slices
#
#                                                                              input  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  2$1/2 cups creamy salad dressing (such as Mira...
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                    3/4 cup prepared yellow mustard
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                                1/4 cup white sugar
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                        2 tablespoons white vinegar
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  12 hard-boiled eggs, peeled and cut into 1/4-i...
#
#                                                   name other       qty  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  creamy salad dressing   NaN  591.4700
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                mustard   NaN       NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS            white sugar   NaN       NaN
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS          white vinegar   NaN   29.5736
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS                   eggs     ,   12.0000
#
#                                 range_end                     title  \
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS       NaN  Creamy Deviled Egg Salad
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS       NaN  Creamy Deviled Egg Salad
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS       NaN  Creamy Deviled Egg Salad
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS       NaN  Creamy Deviled Egg Salad
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS       NaN  Creamy Deviled Egg Salad
#
#                                         unit
# index
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  milliliters
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  milliliters
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  milliliters
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS  milliliters
# ../AFIrLizRK7C5isREQ0hUdXoNXTpS          NaN

# %% [markdown]
# ## I don't use below for Correlation

# %%
# Now we can explore the results of our parsing
print("Unique units of measurement:\n", ingredient_df.unit.unique())
print("Number of unique ingredients: ", len(ingredient_df.name.unique()))
ingredient_df.name.unique()
temp_df = ingredient_df[ingredient_df.name.str.contains("honey")]
temp_df.name.unique()
# Out:
# Unique units of measurement:
#  ['milliliters' nan 'clove' 'grams' 'slice' 'head' 'bunch' 'strip' 'inch'
#  'sprig' 'stalk' 'package' 'packet' 'milliliter' 'scoop' 'ear' 'bulb'
#  'pound fillet' 'piece' 'wedge' 'cup clove' 'sheet' 'gram' 'loaf' 'stick'
#  'ounce fillet' 'splash' 'inch slice' 'fluid' 'envelope' 'ounce slice'
#  'bunch stalk' 'fillet' 'cube' 'bottle' 'head clove' 'leaf' 'cup fillet'
#  'clove clove' 'ball' 'ounce pound' 'rack' 'stalk stalk' 'bone'
#  'bulb clove' 'box' 'square' 'bag' 'pound slice' 'cup slice'
#  'cup teaspoon' 'link' 'head bulb' 'chunk' 'inch sprig' 'cup cup' 'jar']
# Number of unique ingredients:  13004
# array(['honey', 'honeydew melon', 'clover honey', 'honey mustard',
#        'honey-flavored barbeque sauce', 'honeycomb beef tripe',
#        'honey Dijon mustard', 'honey-glazed almonds', 'raw honey',
#        'soft cream cheese with honey and nuts', 'honeydew',
#        'avocado honey', 'honey-Dijon mustard',
#        'honey mustard barbecue sauce', 'orange blossom honey',
#        'white corn syrup or honey', 'fluid honey syrup',
#        'honey- and herb-flavored whiskey liqueur', 'honey graham cereal',
#        'honey mustard sauce', 'honey barbecue sauce',
#        'honeydew melon balls', 'powdered honey', 'honey-flavored butter',
#        'warm honey', 'unpasteurized honey', 'unpasteurized Manuka honey',
#        'honey ham', 'liquid honey', 'honey mustard dressing',
#        'honey (fireweed honey preferred)',
#        'vanilla and honey Greek yogurt', 'honey garlic barbecue sauce',
#        'honey graham crackers', 'honey barbeque sauce', 'honeycomb tripe',
#        'wildflower honey', "Annie's Bunny Grahams honey snacks",
#        'honey garlic sauce', 'Greek-style honey-flavored yogurt',
#        'honeydew melons', 'thyme honey', 'honey hickory barbeque sauce',
#        'organic oats and honey granola', 'deli honey ham',
#        'honey-vanilla almond milk', 'honey mustard salad dressing',
#        'honey-roasted sliced almonds', 'manuka honey',
#        'honey roasted peanuts', 'honey maple syrup',
#        '(1.5 fluid ounce) jigger honey liqueur',
#        'honey mustard salad dressing mix',
#        'honeydew melon, fruit removed with a melon baller',
#        'honey teriyaki sauce', 'honey or molasses',
#        'honey nut-flavored cereal squares', 'honey flavored bacon',
#        'honey Dijon salad dressing', 'mangos honey',
#        'honey graham cracker crumbs', 'agave nectar or honey',
#        'honey baked ham, cut into 1/2 inch cubes',
#        'honey and nut flavor cornflakes cereal',
#        'honey mustard and onion pretzels', 'dijon honey mustard',
#        'honey turkey'], dtype=object)

# %%
# Now we make the real DataFrame that we will do most of our work with.
# In theory this should have worked with .pivot instead of .pivot_table,
# but it didn't. This makes me think there is a bug somewhere in how
# the recipes are being parsed but I will look into that later
# FYI this will take several minutes
recipe_df = ingredient_df.pivot_table(
    index="index", columns="name", values="qty", aggfunc=np.mean
)
recipe_df.fillna(0, inplace=True)
recipe_df.head(10)

# %%
# Let's save our dataframe so we can look at it without having to reload and recompute everything later.
# pickle is much faster than csv
recipe_df.to_pickle("data/"+file_name+"_parsed.pickle")

# %%
# Here we compute the t-SNE
# WARNING: THIS TAKES A LONG TIME FOR LARGE DATAFRAMES
data = recipe_df[recipe_df.columns].values
tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=5000)
tsne_results = tsne.fit_transform(data)
print("tsne done")
recipe_df["tsne-2d-one"] = tsne_results[:, 0]
recipe_df["tsne-2d-two"] = tsne_results[:, 1]

# %%
# plot the t-SNE
plt.figure(figsize=(16, 10))
sns.scatterplot(x="tsne-2d-one", y="tsne-2d-two", data=recipe_df, linewidth=0)
plt.show()

# %%
# Here I'm just exploring outliers in the t-SNE
sample_df = recipe_df.loc[recipe_df["tsne-2d-two"] <= -100]
drop_cols = sample_df.columns[(sample_df == 0).sum() == sample_df.shape[0]]
sample_df.drop(drop_cols, axis=1, inplace=True)
sample_df.columns.unique()
